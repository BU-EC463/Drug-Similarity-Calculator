# %%
# Let's open and read the content of the uploaded file to understand its structure and data.
file_path = 'Daily Snapshot.csv'

# Reading the file
import pandas as pd

# Load the data from the CSV file
data = pd.read_csv(file_path)
data.head()  # Display the first few rows of the dataframe to understand its structure.
# Out:
#    Item Number – 6 digit   NDC Number    UPC Number                  Constant  \
# 0                   1091  51672408306  351672408367
# 1                   1103  00023334807  300233348079
# 2                   1141  00093227234  300932272347
# 3                   1457  51991062033  351991620334
# 4                   1479               070610209162
#
#   Customer-Specific Item Number                     Description  \
# 0                                HYDROCORTISONE BUTYRATE 0.1% O
# 1                                OZURDEX IMP 1 DS
# 2                                AMOXICILLIN-CLAV K 400-57 MG C
# 3                                ANASTROZOLE 1 MG TAB 30
# 4                                BERRY OINTMENT JAR 916 WHITE 1
#
#    Pack Size Divisor  Size Qty RX/OTC Indicator  AWP Price  Acquisition Price  \
# 0              45000  45                      R      17928               9425
# 1               1000                          R     164760             137300
# 2              20000  20                      R      11751               5038
# 3              30000  30                      R      40038                831
# 4               1000  12                      O          0               4641
#
#    Retail Price Contract Flag             Generic Description  \
# 0             0             C  hydrocortisone butyrate TOPICA
# 1             0             N  dexamethasone INTRAOCULR IMPLA
# 2             0             C  amoxicillin/potassium clav ORA
# 3             0             N  anastrozole ORAL TABLET 1 MG
# 4          6962             N
#
#    Retail Pack Quantity  WAC Price  Item Number – 8 digit
# 0                     1      14342               10000009
# 1                     1     137300               10083412
# 2                     1       8814               10000013
# 3                     1        900               10083430
# 4                     1       4641               10000056

# %%
# Removing the specified columns and reordering the 'Item Number – 8 digit' column
columns_to_remove = ['Item Number – 6 digit', 'UPC Number', 'Constant', 
                     'Customer-Specific Item Number', 'Pack Size Divisor', 
                     'RX/OTC Indicator']

# Removing the columns
data_cleaned = data.drop(columns=columns_to_remove)

# Reordering 'Item Number – 8 digit' to the left
column_to_move = data_cleaned.pop('Item Number – 8 digit')
data_cleaned.insert(0, 'Item Number – 8 digit', column_to_move)

# Displaying the first few rows of the modified dataframe
data_cleaned.head()
# Out:
#    Item Number – 8 digit   NDC Number                     Description  \
# 0               10000009  51672408306  HYDROCORTISONE BUTYRATE 0.1% O
# 1               10083412  00023334807  OZURDEX IMP 1 DS
# 2               10000013  00093227234  AMOXICILLIN-CLAV K 400-57 MG C
# 3               10083430  51991062033  ANASTROZOLE 1 MG TAB 30
# 4               10000056               BERRY OINTMENT JAR 916 WHITE 1
#
#    Size Qty  AWP Price  Acquisition Price  Retail Price Contract Flag  \
# 0  45            17928               9425             0             C
# 1               164760             137300             0             N
# 2  20            11751               5038             0             C
# 3  30            40038                831             0             N
# 4  12                0               4641          6962             N
#
#               Generic Description  Retail Pack Quantity  WAC Price
# 0  hydrocortisone butyrate TOPICA                     1      14342
# 1  dexamethasone INTRAOCULR IMPLA                     1     137300
# 2  amoxicillin/potassium clav ORA                     1       8814
# 3  anastrozole ORAL TABLET 1 MG                       1        900
# 4                                                     1       4641

# %%
# Moving all price columns and the contract flag to the right
columns_to_move = ['AWP Price', 'Acquisition Price', 'Retail Price', 'WAC Price', 'Contract Flag']

# Reordering the columns
for col in columns_to_move:
    data_cleaned[col] = data_cleaned.pop(col)

# Displaying the first few rows of the rearranged dataframe
data_cleaned.head()
# Out:
#    Item Number – 8 digit   NDC Number                     Description  \
# 0               10000009  51672408306  HYDROCORTISONE BUTYRATE 0.1% O
# 1               10083412  00023334807  OZURDEX IMP 1 DS
# 2               10000013  00093227234  AMOXICILLIN-CLAV K 400-57 MG C
# 3               10083430  51991062033  ANASTROZOLE 1 MG TAB 30
# 4               10000056               BERRY OINTMENT JAR 916 WHITE 1
#
#    Size Qty             Generic Description  Retail Pack Quantity  AWP Price  \
# 0  45        hydrocortisone butyrate TOPICA                     1      17928
# 1            dexamethasone INTRAOCULR IMPLA                     1     164760
# 2  20        amoxicillin/potassium clav ORA                     1      11751
# 3  30        anastrozole ORAL TABLET 1 MG                       1      40038
# 4  12                                                           1          0
#
#    Acquisition Price  Retail Price  WAC Price Contract Flag
# 0               9425             0      14342             C
# 1             137300             0     137300             N
# 2               5038             0       8814             C
# 3                831             0        900             N
# 4               4641          6962       4641             N

# %%
import re

# Function to split the generic description into generic name and form
def split_description(desc):
    # Find the index of the first capital letter
    match = re.search(r'[A-Z]', desc)
    if match:
        index = match.start()
        return desc[:index].strip(), desc[index:].strip()
    else:
        return desc, ''

# Applying the function to the 'Generic Description' column
data_cleaned['Generic Name'], data_cleaned['Form'] = zip(*data_cleaned['Generic Description'].apply(split_description))

# Dropping the original 'Generic Description' column
data_cleaned.drop(columns=['Generic Description'], inplace=True)

# Displaying the first few rows of the updated dataframe
data_cleaned.head()
# Out:
#    Item Number – 8 digit   NDC Number                     Description  \
# 0               10000009  51672408306  HYDROCORTISONE BUTYRATE 0.1% O
# 1               10083412  00023334807  OZURDEX IMP 1 DS
# 2               10000013  00093227234  AMOXICILLIN-CLAV K 400-57 MG C
# 3               10083430  51991062033  ANASTROZOLE 1 MG TAB 30
# 4               10000056               BERRY OINTMENT JAR 916 WHITE 1
#
#    Size Qty  Retail Pack Quantity  AWP Price  Acquisition Price  Retail Price  \
# 0  45                           1      17928               9425             0
# 1                               1     164760             137300             0
# 2  20                           1      11751               5038             0
# 3  30                           1      40038                831             0
# 4  12                           1          0               4641          6962
#
#    WAC Price Contract Flag                    Generic Name              Form
# 0      14342             C         hydrocortisone butyrate            TOPICA
# 1     137300             N                   dexamethasone  INTRAOCULR IMPLA
# 2       8814             C      amoxicillin/potassium clav               ORA
# 3        900             N                     anastrozole  ORAL TABLET 1 MG
# 4       4641             N

# %%
# Removing rows where the 'Generic Name' is empty or consists only of whitespace
data_cleaned = data_cleaned[data_cleaned['Generic Name'].str.strip() != '']

# Displaying the first few rows of the updated dataframe
data_cleaned.head()
# Out:
#    Item Number – 8 digit   NDC Number                     Description  \
# 0               10000009  51672408306  HYDROCORTISONE BUTYRATE 0.1% O
# 1               10083412  00023334807  OZURDEX IMP 1 DS
# 2               10000013  00093227234  AMOXICILLIN-CLAV K 400-57 MG C
# 3               10083430  51991062033  ANASTROZOLE 1 MG TAB 30
# 5               10083433  67457022005  ISOSULFAN BLUE 1% SDV 6X5 ML
#
#    Size Qty  Retail Pack Quantity  AWP Price  Acquisition Price  Retail Price  \
# 0  45                           1      17928               9425             0
# 1                               1     164760             137300             0
# 2  20                           1      11751               5038             0
# 3  30                           1      40038                831             0
# 5  6X5                          1     763841             587712             0
#
#    WAC Price Contract Flag                Generic Name              Form
# 0      14342             C     hydrocortisone butyrate            TOPICA
# 1     137300             N               dexamethasone  INTRAOCULR IMPLA
# 2       8814             C  amoxicillin/potassium clav               ORA
# 3        900             N                 anastrozole  ORAL TABLET 1 MG
# 5     636534             N              isosulfan blue   SUBCUT VIAL 1 %

# %%
# Function to split the description into name and size
def split_description_on_number(desc):
    # Find the index of the first number
    match = re.search(r'\d', desc)
    if match:
        index = match.start()
        return desc[:index].strip(), desc[index:].strip()
    else:
        return desc, ''

# Applying the function to the 'Description' column
data_cleaned['Name'], data_cleaned['Size'] = zip(*data_cleaned['Description'].apply(split_description_on_number))

# Dropping the original 'Description' column
data_cleaned.drop(columns=['Description'], inplace=True)

# Displaying the first few rows of the updated dataframe
data_cleaned.head()
# Out:
#    Item Number – 8 digit   NDC Number  Size Qty  Retail Pack Quantity  \
# 0               10000009  51672408306  45                           1
# 1               10083412  00023334807                               1
# 2               10000013  00093227234  20                           1
# 3               10083430  51991062033  30                           1
# 5               10083433  67457022005  6X5                          1
#
#    AWP Price  Acquisition Price  Retail Price  WAC Price Contract Flag  \
# 0      17928               9425             0      14342             C
# 1     164760             137300             0     137300             N
# 2      11751               5038             0       8814             C
# 3      40038                831             0        900             N
# 5     763841             587712             0     636534             N
#
#                  Generic Name              Form                     Name  \
# 0     hydrocortisone butyrate            TOPICA  HYDROCORTISONE BUTYRATE
# 1               dexamethasone  INTRAOCULR IMPLA              OZURDEX IMP
# 2  amoxicillin/potassium clav               ORA       AMOXICILLIN-CLAV K
# 3                 anastrozole  ORAL TABLET 1 MG              ANASTROZOLE
# 5              isosulfan blue   SUBCUT VIAL 1 %           ISOSULFAN BLUE
#
#             Size
# 0         0.1% O
# 1           1 DS
# 2    400-57 MG C
# 3    1 MG TAB 30
# 5  1% SDV 6X5 ML

# %%
# Filtering the dataset for items with the exact generic name "lidocaine"
data_lidocaine = data_cleaned[data_cleaned['Generic Name'].str.lower() == 'cyclophosphamide']

data_lidocaine
# Out:
#        Item Number – 8 digit   NDC Number  Size Qty  Retail Pack Quantity  \
# 7913                10141322  00054038225  100                          1
# 7914                10141323  00054038325  100                          1
# 8814                10145810  00781323394                               1
# 8815                10145698  00781324494                               1
# 8816                10145699  00781325594                               1
# 14060               10253816  10019098401  100                          1
# 14061               10253817  10019098201  100                          1
# 17105               10176522  38779050605  100                          1
# 21404               10251866  68001044432                               1
# 21405               10251921  68001044327                               1
# 21406               10251835  68001044226                               1
# 22289               10253968  70860021803  2.5                          1
# 22313               10254172  70860021805  5                            1
# 22446               10238211  50742052005  5                            1
# 22447               10238183  50742051902  2.5                          1
# 23158               10282536  62332061831  100                          1
# 23160               10282568  62332061931  100                          1
# 24962               10263685  50742052110  10                           1
# 25571               10263403  70860021810  10                           1
# 26580               10261686  55150027001  2.5                          1
# 26602               10261764  55150027101  5                            1
# 27507               10281650  43598066111  2                            1
# 27508               10281660  43598066011  1                            1
# 30502               10274636  68001056422  5                            1
# 30514               10274664  68001056528  10                           1
# 31798               10188530  70121123901                               1
# 31799               10188531  70121124001                               1
# 31800               10188532  70121123801                               1
# 33161               10189871  54879002201  100                          1
# 33163               10189872  54879002101  100                          1
# 34868               10211816  69097051707  100                          1
# 34869               10211817  69097051607  100                          1
# 39771               10061501  10019095701                               1
# 39772               10061502  10019095601                               1
# 39773               10061503  10019095501                               1
#
#        AWP Price  Acquisition Price  Retail Price  WAC Price Contract Flag  \
# 7913       93620              69150             0      74894             N
# 7914      171811             126908             0     137450             N
# 8814       41203               8144             0      28019             C
# 8815       82406              18097             0      56036             C
# 8816      164813              40899             0     112073             C
# 14060      50519              15327             0      42099             C
# 14061      35352              10711             0      29460             C
# 17105    1618330              69750             0      69750             N
# 21404     175800             135264             0     146500             N
# 21405      87900              67632             0      73250             N
# 21406      43950              33816             0      36625             N
# 22289      43950              12580             0      36625             C
# 22313      87900              25183             0      73250             C
# 22446      87900              25183             0      73250             C
# 22447      43950              12580             0      36625             C
# 23158      89807              15546             0      16837             N
# 23160     164939              27030             0      29275             N
# 24962     175800              50389             0     146500             C
# 25571     175800              50389             0     146500             C
# 26580      43800              33701             0      36500             N
# 26602      87600              67401             0      73000             N
# 27507      87600              67401             0      73000             N
# 27508      43800              33701             0      36500             N
# 30502      87900              67632             0      73250             N
# 30514     175800             135264             0     146500             N
# 31798      79110              17368             0      65925             C
# 31799     158220              37054             0     131850             C
# 31800      39556               9264             0      32963             C
# 33161      48000              26566             0      40000             C
# 33163      34200              22269             0      28500             C
# 34868     177490              50782             0      55000             N
# 34869      91988              27699             0      30000             N
# 39771     175800              51724             0     146500             C
# 39772      87900              27223             0      73250             C
# 39773      43950              13612             0      36625             C
#
#            Generic Name           Form                  Name           Size
# 7913   cyclophosphamide   ORAL CAPSULE         CYCLOPHOSPHAM  25 MG CAP 100
# 7914   cyclophosphamide   ORAL CAPSULE         CYCLOPHOSPHAM  50 MG CAP 100
# 8814   cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE     500 MG SDV
# 8815   cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE       1 GM SDV
# 8816   cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE       2 GM SDV
# 14060  cyclophosphamide  ORAL TABLET 5      CYCLOPHOSPHAMIDE  50 MG TAB 100
# 14061  cyclophosphamide  ORAL TABLET 2      CYCLOPHOSPHAMIDE  25 MG TAB 100
# 17105  cyclophosphamide  MISCELL POWDE  CYCLOPHOSPHAMIDE USP      100 GM DS
# 21404  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE       2 GM SDV
# 21405  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE       1 GM SDV
# 21406  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE     500 MG SDV
# 22289  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  500 MG MDV 2.
# 22313  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  1 GM MDV 5 ML
# 22446  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  1 GM MDV 5 ML
# 22447  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  500 MG MDV 2.
# 23158  cyclophosphamide   ORAL CAPSULE      CYCLOPHOSPHAMIDE  25 MG CAP 100
# 23160  cyclophosphamide   ORAL CAPSULE      CYCLOPHOSPHAMIDE  50 MG CAP 100
# 24962  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  2 GM MDV 10 M
# 25571  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  2 GM MDV 10 M
# 26580  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  500 MG SDV 2.
# 26602  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  1 GM SDV 5 ML
# 27507  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  1 GM SDV 2 ML
# 27508  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE   500 MG SDV 1
# 30502  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  1 GM MDV 5 ML
# 30514  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE  2 GM MDV 10 M
# 31798  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE       1 GM SDV
# 31799  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE       2 GM SDV
# 31800  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE     500 MG SDV
# 33161  cyclophosphamide   ORAL CAPSULE      CYCLOPHOSPHAMIDE  50 MG CAP 100
# 33163  cyclophosphamide   ORAL CAPSULE      CYCLOPHOSPHAMIDE  25 MG CAP 100
# 34868  cyclophosphamide   ORAL CAPSULE      CYCLOPHOSPHAMIDE  50 MG CAP 100
# 34869  cyclophosphamide   ORAL CAPSULE      CYCLOPHOSPHAMIDE  25 MG CAP 100
# 39771  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE       2 GM SDV
# 39772  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE       1 GM SDV
# 39773  cyclophosphamide  INTRAVEN VIAL      CYCLOPHOSPHAMIDE      500 MG VL

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Selecting the reference item
reference_item_number = 10061501
reference_item = data_lidocaine[data_lidocaine['Item Number – 8 digit'] == reference_item_number]

# Check if the reference item is found
if reference_item.empty:
    similarity_results = "Reference item not found in the dataset."
else:
    # Extracting the form of the reference item
    reference_form = reference_item.iloc[0]['Form']

    # Preparing data for TF-IDF vectorization (including the reference form)
    forms = data_lidocaine['Form'].tolist()
    forms.insert(0, reference_form)

    # Vectorizing the forms using TF-IDF
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(forms)

    # Calculating cosine similarity
    cosine_similarities = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:]).flatten()

    # Adding the similarity scores to the lidocaine dataset
    # We exclude the first element of cosine_similarities as it is the similarity of the reference item with itself
    data_lidocaine['Form Similarity'] = cosine_similarities

    # Displaying the dataset with similarity scores
    similarity_results = data_lidocaine

  # Display the first few rows of the results

# Filtering the dataset to show only items with a similarity score above 0.9
similarity_items = data_lidocaine[data_lidocaine['Form Similarity'] > 0.9]

similarity_items
# Out:
# /var/folders/kw/4fz3zlmn44z83gf65j53lt2w0000gn/T/ipykernel_56591/446726106.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_lidocaine['Form Similarity'] = cosine_similarities
#        Item Number – 8 digit   NDC Number  Size Qty  Retail Pack Quantity  \
# 8814                10145810  00781323394                               1
# 8815                10145698  00781324494                               1
# 8816                10145699  00781325594                               1
# 21404               10251866  68001044432                               1
# 21405               10251921  68001044327                               1
# 21406               10251835  68001044226                               1
# 22289               10253968  70860021803  2.5                          1
# 22313               10254172  70860021805  5                            1
# 22446               10238211  50742052005  5                            1
# 22447               10238183  50742051902  2.5                          1
# 24962               10263685  50742052110  10                           1
# 25571               10263403  70860021810  10                           1
# 26580               10261686  55150027001  2.5                          1
# 26602               10261764  55150027101  5                            1
# 27507               10281650  43598066111  2                            1
# 27508               10281660  43598066011  1                            1
# 30502               10274636  68001056422  5                            1
# 30514               10274664  68001056528  10                           1
# 31798               10188530  70121123901                               1
# 31799               10188531  70121124001                               1
# 31800               10188532  70121123801                               1
# 39771               10061501  10019095701                               1
# 39772               10061502  10019095601                               1
# 39773               10061503  10019095501                               1
#
#        AWP Price  Acquisition Price  Retail Price  WAC Price Contract Flag  \
# 8814       41203               8144             0      28019             C
# 8815       82406              18097             0      56036             C
# 8816      164813              40899             0     112073             C
# 21404     175800             135264             0     146500             N
# 21405      87900              67632             0      73250             N
# 21406      43950              33816             0      36625             N
# 22289      43950              12580             0      36625             C
# 22313      87900              25183             0      73250             C
# 22446      87900              25183             0      73250             C
# 22447      43950              12580             0      36625             C
# 24962     175800              50389             0     146500             C
# 25571     175800              50389             0     146500             C
# 26580      43800              33701             0      36500             N
# 26602      87600              67401             0      73000             N
# 27507      87600              67401             0      73000             N
# 27508      43800              33701             0      36500             N
# 30502      87900              67632             0      73250             N
# 30514     175800             135264             0     146500             N
# 31798      79110              17368             0      65925             C
# 31799     158220              37054             0     131850             C
# 31800      39556               9264             0      32963             C
# 39771     175800              51724             0     146500             C
# 39772      87900              27223             0      73250             C
# 39773      43950              13612             0      36625             C
#
#            Generic Name           Form              Name           Size  \
# 8814   cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE     500 MG SDV
# 8815   cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       1 GM SDV
# 8816   cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       2 GM SDV
# 21404  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       2 GM SDV
# 21405  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       1 GM SDV
# 21406  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE     500 MG SDV
# 22289  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  500 MG MDV 2.
# 22313  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM MDV 5 ML
# 22446  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM MDV 5 ML
# 22447  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  500 MG MDV 2.
# 24962  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  2 GM MDV 10 M
# 25571  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  2 GM MDV 10 M
# 26580  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  500 MG SDV 2.
# 26602  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM SDV 5 ML
# 27507  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM SDV 2 ML
# 27508  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE   500 MG SDV 1
# 30502  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM MDV 5 ML
# 30514  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  2 GM MDV 10 M
# 31798  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       1 GM SDV
# 31799  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       2 GM SDV
# 31800  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE     500 MG SDV
# 39771  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       2 GM SDV
# 39772  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       1 GM SDV
# 39773  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE      500 MG VL
#
#        Form Similarity
# 8814               1.0
# 8815               1.0
# 8816               1.0
# 21404              1.0
# 21405              1.0
# 21406              1.0
# 22289              1.0
# 22313              1.0
# 22446              1.0
# 22447              1.0
# 24962              1.0
# 25571              1.0
# 26580              1.0
# 26602              1.0
# 27507              1.0
# 27508              1.0
# 30502              1.0
# 30514              1.0
# 31798              1.0
# 31799              1.0
# 31800              1.0
# 39771              1.0
# 39772              1.0
# 39773              1.0

# %%
# Extracting the size of the reference item
reference_size = reference_item.iloc[0]['Size']

# Preparing data for TF-IDF vectorization (including the reference size)
sizes = similarity_items['Size'].tolist()
sizes.insert(0, reference_size)

# Vectorizing the sizes using TF-IDF
tfidf_matrix_sizes = vectorizer.fit_transform(sizes)

# Calculating cosine similarity for sizes
cosine_similarities_sizes = cosine_similarity(tfidf_matrix_sizes[0:1], tfidf_matrix_sizes[1:]).flatten()

# Adding the similarity scores for sizes to the high_similarity_items dataset
# We exclude the first element of cosine_similarities_sizes as it is the similarity of the reference item with itself
similarity_items['Size Similarity'] = cosine_similarities_sizes

# Displaying the dataset with size similarity scores
high_similarity_items_filtered_by_size = similarity_items[similarity_items['Size Similarity'] > 0.25]
# high_similarity_items_filtered_by_size  # Display the first few rows of the results

# Sorting the results by 'Size Similarity' in descending order
sorted_similarity_items = high_similarity_items_filtered_by_size.sort_values(by='Size Similarity', ascending=False)
sorted_similarity_items  # Display the first few rows of the sorted results
# Out:
# /var/folders/kw/4fz3zlmn44z83gf65j53lt2w0000gn/T/ipykernel_56591/1837479826.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   similarity_items['Size Similarity'] = cosine_similarities_sizes
#        Item Number – 8 digit   NDC Number  Size Qty  Retail Pack Quantity  \
# 39772               10061502  10019095601                               1
# 8815                10145698  00781324494                               1
# 8816                10145699  00781325594                               1
# 21404               10251866  68001044432                               1
# 21405               10251921  68001044327                               1
# 39771               10061501  10019095701                               1
# 31799               10188531  70121124001                               1
# 31798               10188530  70121123901                               1
# 27507               10281650  43598066111  2                            1
# 26602               10261764  55150027101  5                            1
# 26580               10261686  55150027001  2.5                          1
# 27508               10281660  43598066011  1                            1
# 31800               10188532  70121123801                               1
# 21406               10251835  68001044226                               1
# 8814                10145810  00781323394                               1
# 30502               10274636  68001056422  5                            1
# 22446               10238211  50742052005  5                            1
# 22313               10254172  70860021805  5                            1
#
#        AWP Price  Acquisition Price  Retail Price  WAC Price Contract Flag  \
# 39772      87900              27223             0      73250             C
# 8815       82406              18097             0      56036             C
# 8816      164813              40899             0     112073             C
# 21404     175800             135264             0     146500             N
# 21405      87900              67632             0      73250             N
# 39771     175800              51724             0     146500             C
# 31799     158220              37054             0     131850             C
# 31798      79110              17368             0      65925             C
# 27507      87600              67401             0      73000             N
# 26602      87600              67401             0      73000             N
# 26580      43800              33701             0      36500             N
# 27508      43800              33701             0      36500             N
# 31800      39556               9264             0      32963             C
# 21406      43950              33816             0      36625             N
# 8814       41203               8144             0      28019             C
# 30502      87900              67632             0      73250             N
# 22446      87900              25183             0      73250             C
# 22313      87900              25183             0      73250             C
#
#            Generic Name           Form              Name           Size  \
# 39772  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       1 GM SDV
# 8815   cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       1 GM SDV
# 8816   cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       2 GM SDV
# 21404  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       2 GM SDV
# 21405  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       1 GM SDV
# 39771  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       2 GM SDV
# 31799  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       2 GM SDV
# 31798  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE       1 GM SDV
# 27507  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM SDV 2 ML
# 26602  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM SDV 5 ML
# 26580  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  500 MG SDV 2.
# 27508  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE   500 MG SDV 1
# 31800  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE     500 MG SDV
# 21406  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE     500 MG SDV
# 8814   cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE     500 MG SDV
# 30502  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM MDV 5 ML
# 22446  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM MDV 5 ML
# 22313  cyclophosphamide  INTRAVEN VIAL  CYCLOPHOSPHAMIDE  1 GM MDV 5 ML
#
#        Form Similarity  Size Similarity
# 39772              1.0         1.000000
# 8815               1.0         1.000000
# 8816               1.0         1.000000
# 21404              1.0         1.000000
# 21405              1.0         1.000000
# 39771              1.0         1.000000
# 31799              1.0         1.000000
# 31798              1.0         1.000000
# 27507              1.0         0.625084
# 26602              1.0         0.625084
# 26580              1.0         0.316861
# 27508              1.0         0.316861
# 31800              1.0         0.316861
# 21406              1.0         0.316861
# 8814               1.0         0.316861
# 30502              1.0         0.271156
# 22446              1.0         0.271156
# 22313              1.0         0.271156
